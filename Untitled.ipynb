# %%
8+7
# Out:
# 15

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
#importing data 
IPV= pd.read_excel("C:/Users/ADDIS/Desktop/PYTHON BEINNER CLASS/IPV Dataset.xlsx")

# %%
IPV
# Out:
#                      start                     end  \
# 0  2024-01-23 21:42:51.720 2024-01-23 21:44:18.745
# 1  2024-01-23 21:42:30.811 2024-01-23 21:44:32.859
# 2  2024-01-23 21:42:36.391 2024-01-23 21:45:02.101
# 3  2024-01-23 21:42:33.448 2024-01-23 21:45:14.769
# 4  2024-01-23 21:42:46.657 2024-01-23 21:45:15.748
# 5  2024-01-23 21:44:18.811 2024-01-23 21:45:25.324
# 6  2024-01-23 21:45:25.397 2024-01-23 21:46:30.475
# 7  2024-01-23 21:42:54.160 2024-01-23 21:49:18.864
# 8  2024-01-23 21:47:00.108 2024-01-23 21:49:37.513
# 9  2024-01-23 12:43:07.725 2024-01-23 12:50:05.615
# 10 2024-01-23 21:54:25.260 2024-01-23 21:57:44.800
# 11 2024-01-23 22:01:01.835 2024-01-23 22:05:22.753
# 12 2024-01-23 22:10:45.965 2024-01-23 22:11:54.980
# 13 2024-01-23 22:12:56.766 2024-01-23 22:15:58.200
# 14 2024-01-23 22:15:58.221 2024-01-23 22:17:25.549
# 15 2024-01-23 21:17:26.865 2024-01-23 21:19:04.629
# 16 2024-01-23 22:46:39.135 2024-01-23 22:48:09.293
# ...

# %%
# Data exploration
print(IPV.columns)
# Out:
# Index(['start', 'end',
#        'SECTION A: SOCIO- DEMOGRAPHIC CHARACTERISTICS OF THE RESPONDENTS',
#        'Age as at last birthday', 'Partner’s age', 'Current marital status',
#        'Family setting', 'If others, please specify', 'Religion',
#        'If others, please specify.1', 'Ethnicity',
#        'If others, please specify.2',
#        'SECTION B: SOCIO-ECONOMIC CHARACTERISTICS OF THE RESPONDENTS',
#        'Employment status', 'Partner’s employment status',
#        'Average income per month', 'Partner’s average income per month',
#        'Your highest level of education',
#        'Your partner’s highest level of education',
#        'SECTION C: PREVALENCE OF INTIMATE PARTNER VIOLENCE',
#        'C1: PREVALENCE OF PHYSICAL VIOLENCE ',
#        'Did your husband or last husband ever do any of the following things to you in the last 6 months: ',
#        'Push you, shake you,\nor throw something at you? ', 'Slap you? ',
#        'Twist your arm or\npull your hair?',
# ...

# %%
# Renaming Variables
IPV.rename(columns={'Age as at last birthday' : 'Age'}, inplace=True)
IPV.rename(columns={'Partner’s age' : 'Partner_ age'}, inplace=True)
IPV.rename(columns={'Current marital status' : 'marital_status'}, inplace=True)

# %%
#descriptive data analysis
IPV.Age.mean()
# Out:
# 34.53703703703704

# %%
IPV.Partner_age.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-2f83de6fe06e> in <module>
# ----> 1 IPV.Partner_age.mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Partner_age'

# %%
IPV.columns
# Out:
# Index(['start', 'end',
#        'SECTION A: SOCIO- DEMOGRAPHIC CHARACTERISTICS OF THE RESPONDENTS',
#        'Age', 'Partner_ age', 'marital_status', 'Family setting',
#        'If others, please specify', 'Religion', 'If others, please specify.1',
#        'Ethnicity', 'If others, please specify.2',
#        'SECTION B: SOCIO-ECONOMIC CHARACTERISTICS OF THE RESPONDENTS',
#        'Employment status', 'Partner’s employment status',
#        'Average income per month', 'Partner’s average income per month',
#        'Your highest level of education',
#        'Your partner’s highest level of education',
#        'SECTION C: PREVALENCE OF INTIMATE PARTNER VIOLENCE',
#        'C1: PREVALENCE OF PHYSICAL VIOLENCE ',
#        'Did your husband or last husband ever do any of the following things to you in the last 6 months: ',
#        'Push you, shake you,\nor throw something at you? ', 'Slap you? ',
#        'Twist your arm or\npull your hair?',
# ...

# %%
#descriptive analysis 2
IPV.Martial_status.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-42f1cd393cf3> in <module>
#       1 #descriptive analysis 2
# ----> 2 IPV.Martial_status.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Martial_status'
