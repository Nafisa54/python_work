# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
df.tail()
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
df.total_profit
# Out:
# 0     211000
# 1     183300
# 2     224700
# 3     222700
# 4     209600
# 5     201400
# 6     295500
# 7     361400
# 8     234000
# 9     266700
# 10    412800
# 11    300200
# Name: total_profit, dtype: int64

# %%
total_profit_sum = df['total_profit'].sum()
print(f"The total profit is: {total_profit_sum}")
# Out:
# The total profit is: 3123300

# %%
plt.figure(figsize=(10, 5))
plt.plot(total_profit, marker='o', linestyle='-', color='b', label='Total Profit')
plt.title('Total Profit of All Months')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True) 
plt.show()

# %%
bathing_soap = df['bathingsoap']
facewash = df['facewash']
fig, ax = plt.subplots(2, 1, figsize=(10, 8))
ax[0].plot(bathing_soap, marker='o', linestyle='-', color='g', label='Bathing Soap Sales')
ax[0].set_title('Bathing Soap Sales of All Months')
ax[0].set_xlabel('Month Number')
ax[0].set_ylabel('Bathing Soap Sales')
ax[0].legend()
ax[0].grid(True)
ax[1].plot(facewash, marker='o', linestyle='-', color='r', label='Facewash Sales')
ax[1].set_title('Facewash Sales of All Months')
ax[1].set_xlabel('Month Number')
ax[1].set_ylabel('Facewash Sales')
ax[1].legend()
ax[1].grid(True)
plt.tight_layout()
plt.show()
